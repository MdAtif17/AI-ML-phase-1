# %% [markdown]
# <a href="https://colab.research.google.com/github/MdAtif17/AI-ML-phase-1/blob/main/Day1%20python%20-%20variables%2C%20Data%20types%2C%20type%20conversion%2C%20input/output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. Store your name in a variable and print it.
name = "atif"
print(name)
# Out:
# atif

# %%
#2. Store your age and print it.
age="12"
print(age)
# Out:
# 12

# %%
#2. Store your age and print it.
college_name = "Sathyabama institute of science and technology"
print(college_name)
# Out:
# Sathyabama institute of science and technology

# %%
#Store your height (float) and weight, then print both.
height="5.6"
weight=50.7
print(float(height))
print(int(weight))
# Out:
# 5.6
# 50

# %%
#5. Store three variables (name, age, city) and print them on separate lines.
name="Atif"
age="19"
city="Chennai"
print(name,age,city)
# Out:
# Atif 19 Chennai

# %%
#6. Store your favorite programming language and years of experience.
language="python"
experience=1

# %%
#7. Create two variables and swap their values without using a third variable.
print("Before Swap:")
a=10
b=20
print(f"a={a},b={b}")
a,b=b,a
print("\nAfter Swap:")
print(f"a={a},b={b}")
# Out:
# Before Swap:
# a=10,b=20
#
# After Swap:
# a=20,b=10

# %%
#8. Store a value in one variable and assign it to another variable.
a=10
b=a
print(a)
print(b)
# Out:
# 10
# 10

# %%
#9. Create multiple variables in one line.
a,b,c=10,20,30
print(a,b,c)
# Out:
# 10 20 30

# %%
#10. Assign the same value to three variables.
a=b=c=100
print(a,b,c)
# Out:
# 100 100 100

# %% [markdown]
# # DATA TYPES

# %%
#11. Store an integer and print its data type.
a=10
print(type(a))
# Out:
# <class 'int'>

# %%
#12. Store a float and print its type.
b=11.5
print(type(b))
# Out:
# <class 'float'>

# %%
#13. Store a string and print its type.
c="atif"
print(type(c))
# Out:
# <class 'str'>

# %%
#14. Store a Boolean value and print its type.
a=True
print(type(a))
# Out:
# <class 'bool'>

# %%
#15. Store a list and print its type.
a=[1,2,3,4]
print(type(a))
# Out:
# <class 'list'>

# %%
#16. Store a tuple and print its type.
a=(1,2,3,4)
print(type(a))
# Out:
# <class 'tuple'>

# %%
#17. Store a set and print its type.
a={1,2,3,4}
print(type(a))
# Out:
# <class 'set'>

# %%
#18. Store a dictionary and print its type.
a={"name":"atif","age":19}
print(type(a))
# Out:
# <class 'dict'>

# %%
#19. Create one variable of every built-in data type and print each value with its type.
a=10
b=10.5
c="atif"
d=True
e=[1,2,3,4]
f=(1,2,3,4)
g={1,2,3,4}
h={"name":"atif","age":19}
print(type(a)),print(a)
print(type(b)),print(b)
print(type(c)),print(c)
print(type(d)),print(d)
print(type(e)),print(e)
print(type(f)),print(f)
print(type(g)),print(g)
print(type(h)),print(h)
# Out:
# <class 'int'>
# 10
# <class 'float'>
# 10.5
# <class 'str'>
# atif
# <class 'bool'>
# True
# <class 'list'>
# [1, 2, 3, 4]
# <class 'tuple'>
# (1, 2, 3, 4)
# <class 'set'>
# {1, 2, 3, 4}
# <class 'dict'>
# {'name': 'atif', 'age': 19}
# (None, None)

# %%
#20. Store a complex number and print its type.
a=1+2j
print(type(a))
# Out:
# <class 'complex'>

# %% [markdown]
# INPUT & OUTPUT

# %%
#21. Take the user's name as input and print:
name=input("Enter your name:")
print (name)
# Out:
# Enter your name:Mohmmed Atif A A
# Mohmmed Atif A A

# %%
#22. Take the user's age and print:
age=int(input("Enter Your Age:"))
print("Your Age is",age)
# Out:
# Enter Your Age:19
# Your Age is 19

# %%
#23. Take two numbers and print their sum.
a=23
b=27
c=a+b
print(c)
# Out:
# 50

# %%
#24. Take two decimal numbers and print their product.
a=23.4
b=26.7
c=a+b
print(float(c))
# Out:
# 50.099999999999994

# %%
#25. Take a student's name and marks, then print them neatly.
name=input("Enter your name:")
age=int(input("Enter your age:"))
print("Name:",name)
print("Age:",age)
# Out:
# Enter your name:Atif
# Enter your age:19
# Name: Atif
# Age: 19

# %%
#26. Take your city and country as input and print them.
city=input("Enter your city:")
country=input("Enter your country:")
print("City:",city)
print("Country:",country)
# Out:
# Enter your city:Chennai
# Enter your country:India
# City: Chennai
# Country: India

# %%
#27. Take your birth year and calculate your current age.
birth_year=int(input("Enter your birth year:"))
current_year=2026
Current_age=current_year-birth_year
print("Current Age:",Current_age)
# Out:
# Enter your birth year:2006
# Current Age: 20

# %%
#28. Take a person's first name and last name separately and print the full name.
first_name=input("Enter your first name:")
last_name=input("Enter your last name:")
print("Full name:",first_name,last_name)
# Out:
# Enter your first name:Atif
# Enter your last name:Ali
# Full name: Atif Ali

# %%
#29. Take the user's favorite AI field (ML, DL, NLP, CV) and print it.
ai_field=input("Enter your favourite Ai field:")
print("AI field:",ai_field)
# Out:
# Enter your favourite Ai field:gemini
# AI field: gemini

# %%
#30. Take three numbers from the user and print them in reverse order.
a=10
b=20
c=30
print("In reverse order:",c,b,a)
# Out:
# In reverse order: 30 20 10

# %% [markdown]
# # Type Conversion
