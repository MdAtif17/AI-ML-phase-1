# %% [markdown]
# <a href="https://colab.research.google.com/github/MdAtif17/AI-ML-phase-1/blob/main/mini_project_1%20student%20info.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Student Information System (Mini Project) which includes name , age , college , reg.no , department , cgpa , email , phone number , city
name=input("Enter your name:")
age=int(input("Enter your age:"))
college=input("Enter your college name:")
reg_no=int(input("Enter your register number:"))
department=input("Enter your departmment:")
cgpa=float(input("Enter your cgpa:"))
email=input("Enter your email:")
phone_number=int(input("Enter your phone number:"))
city=input("Enter your city:")
print("--------------------------------")
print("--------------------------------")
print("Student Information System")
print("--------------------------------")
print("--------------------------------")
print("Name:",name)
print("Age:",age)
print("College:",college)
print("Register Number:",reg_no)
print("Department:",department)
print("CGPA:",cgpa)
print("Email:",email)
print("Phone Number:",phone_number)
print("City:",city)
print("--------------------------------")
primt("--------------------------------")
# Out:
# Enter your name:Atif
# Enter your age:19
# Enter your college name:Sathyabama University
# Enter your register number:44131028
# Enter your departmment:ECE
# Enter your cgpa:7.75
# Enter your email:aatiflucky666@gmail.com
# Enter your phone number:8015115210
# Enter your city:Chennai
# --------------------------------
# --------------------------------
# Student Information System
# --------------------------------
# --------------------------------
# Name: Atif
# Age: 19
# College: Sathyabama University
# Register Number: 44131028
# Department: ECE
# CGPA: 7.75
# Email: aatiflucky666@gmail.com
# Phone Number: 8015115210
# City: Chennai
# --------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_962/1718261979.py in <cell line: 0>()
#      24 print("City:",city)
#      25 print("--------------------------------")
# ...

# %% [markdown]
# # BMI BASED MINI PROJECT

# %%
name=input("Enter your name:")
age=int(input("Enter your age:"))
height=float(input("Enter your height in meters:"))
weight=float(input("Enter your weight in kg:"))
bmi=weight/(height**2)
print("--------------------------------")
print("--------------------------------")
print("BMI BASED MINI PROJECT")
print("--------------------------------")
print("--------------------------------")
print("Name:",name)
print("Age:",age)
print("Height:",height)
print("Weight:",weight)
print("BMI:",bmi)
print("--------------------------------")
print("--------------------------------")
# Out:
# Enter your name:Atif
# Enter your age:19
# Enter your height in meters:5.6
# Enter your weight in kg:56
# --------------------------------
# --------------------------------
# BMI BASED MINI PROJECT
# --------------------------------
# --------------------------------
# Name: Atif
# Age: 19
# Height: 5.6
# Weight: 56.0
# BMI: 1.785714285714286
# --------------------------------
# --------------------------------

# %% [markdown]
# # CURRENCY CONVERTOR

# %%
amount=int(input("Enter the amount:"))
exchange_rate=float(input("Enter the exchange rate:"))
currency=amount*exchange_rate
print("--------------------------------")
print("--------------------------------")
print("CURRENCY CONVERTOR")
print("--------------------------------")
print("--------------------------------")
print("Amount:",amount)
print("Exchange Currency:",exchange_currency)
print("Currency:",currency)
print("--------------------------------")
# Out:
# Enter the amount:100
# Enter the exchange rate:83.5
# --------------------------------
# --------------------------------
# CURRENCY CONVERTOR
# --------------------------------
# --------------------------------
# Amount: 100
# Exchange Currency: 83.5
# Currency: 8350.0
# --------------------------------
